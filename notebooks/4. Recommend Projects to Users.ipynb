# %% [markdown]
# # Recommend Projects to Users

# %%
from keras.models import load_model
from sklearn.metrics.pairwise import cosine_similarity
import pandas as pd
import numpy as np
np.random.seed(0)
from time import gmtime, strftime
from keras.models import Model
from scipy.sparse import vstack

import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
from src.evaluate import evaluate
from src.recommender import Recommender
import src.load_data as load_data
# Out:
# Using TensorFlow backend.

# %%
# Load the projects dataframe
projects = pd.read_pickle("../data/raw/project_data")

# %%
# Load the autoencoder to reduce the dimensionality of our TF-IDF vectors
model = load_model('autoencoder.h5')
# Out:
# WARNING:tensorflow:From /Users/thomascartwright/miniconda3/envs/cdea/lib/python3.6/site-packages/tensorflow/python/ops/control_flow_ops.py:423: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /Users/thomascartwright/miniconda3/envs/cdea/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /Users/thomascartwright/miniconda3/envs/cdea/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.

# %%
# Load the proejct data
train_projects, train_x, test_projects, test_x, train_project_ids, test_project_ids = load_data.load_projects()
train_x_projects = np.array(train_projects, dtype=np.int32).reshape(len(train_projects), 1)
test_x_projects = np.array(test_projects, dtype=np.int32).reshape(len(test_projects), 1)

# Prepare our variables to be used in recommendation
x = vstack([train_x, test_x])
x_projects = train_projects + test_projects
x_project_ids = train_project_ids + test_project_ids

# Load the users projects
users_projects = load_data.load_user()

# %%
# Create a model that we will use to extract the embedding layer output
embed_model = Model(inputs=model.input, outputs=model.get_layer('embedding_layer').output)

# The dimension that the TF-IDF vector will be reduced to
embedding_size = model.get_layer('embedding_layer').output_shape[2]

# Embed our TF-IDF Vectors for all Projects
embeddings = embed_model.predict(x=[x, np.array(x_projects, dtype=np.int32).reshape(len(x_projects), 1)]).reshape(len(x_projects), embedding_size)

# %% [markdown]
# ### Make Recommendations for a User

# %%
# Initialise our recommender class
rec = Recommender(x_project_ids)

# Calculate our cosine similarity matrix between all projects
similarity_matrix = rec.similarity(embeddings)

# %% [markdown]
# # Select a user to recommend projects to

# %%
# Select a user that we will recommend projects to
user_idx = 3999 # select any number between 0 and 4000

# Reshape our user_projects vector
user_projects = users_projects[user_idx].todense()
user_projects = np.array((user_projects.T))

# Count the number of projects this user has interacted with
ones_idx = np.nonzero(user_projects)
num_ones = len(np.array(ones_idx).flatten())
print("This user has interacted with " + str(num_ones) + " projects.")

# Get the top recommender projects
done_projects, top_projects = rec.top_projects(similarity_matrix, user_projects)
# Out:
# This user has interacted with 134 projects.

# %%
# Display the projects that we suggested the user take part in
recommended_project_ids = list(top_projects['project_id'])
recommender_projects = projects[projects['project_id'].isin(recommended_project_ids)]
recommender_projects
# Out:
#      UN_regions        country  \
# 0            []
# 1131         []           None
# 1132         []           None
# 1133         []           None
# 1134         []
# 1135         []
# 1136         []
# 1137         []           None
# 1138         []  United States
# 1139         []
# 1140         []           None
# 1141         []
# 1142         []
# 1143         []
# 1144         []
# 1145         []
# 1146         []
# 1147         []
# 1148         []
# 1149         []
# 1150         []
# 1151         []
# 1152         []
# 1153         []
# 1154         []
# 1155         []           None
# 1156         []          28768
# 1158         []
# 1159         []
# 1160         []
# ...         ...            ...
# 1213         []
# 1214         []           None
# 1215         []
# 1216         []
# 1217         []
# 1218         []           None
# 1219         []
# 1220         []
# 1221         []           None
# 1222         []
# 1223         []
# 1224         []
# 1225         []           None
# 1226         []
# 1227         []      Australia
# 1228         []
# 1229         []
# 1230         []
# 1231         []
# 1232         []           None
# 1233         []
# 1234         []
# 1235         []
# 1236         []
# 1237         []
# 1238         []
# 1239         []           None
# 1240         []           None
# 1241         []
# 1350         []
#
#                                             description error  \
# 0     Foldit is a revolutionary new computer game en...   NaN
# 1131  CMN aims to promote planning sustainable commu...   NaN
# 1132  Help us track monarch and milkweed occurrences...   NaN
# 1133  Welcome to GLOBE Observer, an international ci...   NaN
# 1134  NECi's handheld photometer sends nitrate & pho...   NaN
# 1135  Global Fishing Watch is the product of a partn...   NaN
# 1136  Participants will help by reporting bats found...   NaN
# 1137  We are scientists at The California Academy of...   NaN
# 1138  Since 1990, surveys have been conducted of hor...   NaN
# 1139  GlobalXplorer° is an online platform that uses...   NaN
# 1140  What's in YOUR water? We all have the right to...   NaN
# 1141  Science in the National Park is an exciting ne...   NaN
# 1142  The electronic Humor to Cope and Connect (e-H2...   NaN
# 1143  The Wisconsin Breeding Bird Atlas II is a comp...   NaN
# 1144  This free webinar will present an overview of ...   NaN
# 1145  Operation Resilient Trees is one of Earthwatch...   NaN
# 1146  Citizen Science Day kicks off on April 14 and ...   NaN
# 1147  What better way to help create a baseline of B...   NaN
# 1148  The volunteer monitoring project was designed ...   NaN
# 1149  Doing It Together Science\r\n\r\nCitizens have...   NaN
# 1150  We are studying microbes in desert rocks to in...   NaN
# 1151  The Blue Carbon Lab has launched a global init...   NaN
# 1152  Nature is full of patterns, which has been gen...   NaN
# 1153  The Andean Biotic Index (ABI) is a measurement...   NaN
# 1154  Is there a large planet at the fringes of our ...   NaN
# 1155  Pl@ntNet is an app which provides you to recog...   NaN
# 1156  A unique way to experience the Blue Ridge Moun...   NaN
# 1158  Mission\r\nEncourage residents and other stake...   NaN
# 1159  The Silver City Watershed Keepers is a citizen...   NaN
# 1160  In the era of data-intensive scientific discov...   NaN
# ...                                                 ...   ...
# 1213                                     all about cats   NaN
# 1214  This project is to help our organization bette...   NaN
# 1215  This project will be at least 85 to 95% 3D pri...   NaN
# 1216  MO DIRT Missourians Doing Impact Research Toge...   NaN
# 1217  We’re looking for volunteers to help us create...   NaN
# 1218  I have over twelve thousand personal research ...   NaN
# 1219  Litter. It’s a pervasive problem with the pote...   NaN
# 1220  A new way of mapping forests from the air by m...   NaN
# 1221  Use the iNaturalist application to participate...   NaN
# 1222  Stream Tracker is community powered stream mon...   NaN
# 1223  CARIB Tails enlists yachters and cruisers to h...   NaN
# 1224  Join the MedLit Blitz: Working together to cre...   NaN
# 1225  Each of the millions of images that has been t...   NaN
# 1226  Scientists are asking the public’s help in sea...   NaN
# 1227  The Reef Recovery program for Magnetic Island ...   NaN
# 1228  At Pacific Whale Foundation we began documenti...   NaN
# 1229  "The River Mile" is a network of educators, st...   NaN
# 1230  Self Guided Trail Brochure that provides oppor...   NaN
[{'geometry': {'type': 'MultiPolygon', 'coordi...
# 1350  [{'geometry': {'type': 'MultiPolygon', 'coordi...
#
#                                                    tags  \
# 0                                        [dna, protein]
# 1131  [community mapping, csim, eelgrass, fiss, inva...
# 1132  [asclepias, danaus plexippus, mapper, milkweed...
# 1133  [app, clouds, girl scouts, globe, internal_gir...
# 1134  [app, neci, nitrate, phosphate, photometer, pl...
# 1135  [data, exclusive economic zone, fish, fisherie...
# 1136                         [bat, bat house, mosquito]
# 1137  [ants, backyard, backyard biodiversity, biodiv...
# 1138  [delaware bay, horseshoe crabs, internal_crowd...
# 1139  [culture, girl scouts, internal_girl_scouts, p...
# 1140  [crowd sourcing, girl scouts, internal_girl_sc...
# 1141                                                 []
# 1142  [humor health stress coping relationships educ...
# 1143                         [birding, birds, breeding]
# 1144                                                 []
# 1145        [climate change, los angeles, trees, urban]
# 1146                                                 []
# 1147                                                 []
# 1148  [cattail, cattail monitoring, hybridization, t...
# 1149  [biodesign, discussion, environment, film, map...
# 1150  [algae, archaea, astrobiology, colonization, c...
# 1151  [blue carbon, carbon climate change data, carb...
# 1152  [bees, bubbles, challenge, chaos, clouds, comp...
# 1153   [andean biotic index, macroinvertebrates, water]
# 1154  [brown dwarfs, planet nine, planets, solar sys...
# 1155  [bark, biodiversity, camera, flora, flower, fl...
# 1156                                                 []
# 1158  [chinook salmon, creek, fish, rivers, stream, ...
# 1159  [volunteer monitoring, water quality, watershe...
# 1160  [citizen science, crowdsourcing, data extracti...
# ...                                                 ...
# 1213                                             [cats]
# 1214                                                 []
# 1215  [3d-parts, 3d-printing, analytical-instrument,...
# 1216     [soil, soil-climate interactions, soil health]
# 1217  [, crowdsourcing, crowdsourcing platform, museum]
# 1218  [chemistry, physical-chemistry, spectral-datab...
# 1219  [debris, litter, microplastic, plastic, policy...
# 1220                                                 []
# 1221         [flowers, honey bees, pollinators/insects]
# 1222  [community, crowd-sourced observations, interm...
# 1223                         [humpback whale caribbean]
# 1224                                                 []
# 1225   [geography, geology, planetary science, planets]
# 1226  [antarctica, antarctic seals, count the seals,...
# 1227  [australia, citizen-science, community, coral ...
# 1228             [beach, clean-up, free, marine debris]
# 1229                         [columbia river, crayfish]
# 1230  [carl sandburg, citizen science, climate, ecos...
# 1231  [behavior, california condor, conservation, en...
# 1232             [pefo, petrified forest national park]
# 1233                                                 []
# 1234                               [, plants, wildlife]
# 1235  [archeology, astronomy & space, chemistry, eco...
# 1236  [flycatcher, migration, nesting citizen scienc...
# 1237  [ages 9-12, ecosystems, environmental stewards...
# 1238  [benthic macroinvertebrates, chesapeake bay, d...
# 1239  [ant, ant picnic, ants, cookies, diet, dunn la...
# 1240                                                 []
# 1241                                                 []
# 1350  [bird banding, bird count, birding, birding ab...
#
#                                                   title  \
# 0                                                Foldit
# 1131                    Community Mapping Network (CMN)
# 1132                    Western Monarch Milkweed Mapper
# 1133                             GLOBE Observer: Clouds
# 1134                         NECi's handheld photometer
# 1135                               Global Fishing Watch
# 1136                                          Got Bats?
# 1137               Backyard Biodiversity Project: Pools
# 1138                     Horseshoe Crab Spawning Survey
# 1139                                     Global Xplorer
# 1149  https://scistarter.com/project/16891-Doing-It-...       16891
# 1150  https://scistarter.com/project/16894-Rockiolog...       16894
# 1151  https://scistarter.com/project/16895-TeaCompos...       16895
# 1152  https://scistarter.com/project/16897-Natural-P...       16897
# 1153  https://scistarter.com/project/16903-Andean-Bi...       16903
# 1154  https://scistarter.com/project/16904-Backyard-...       16904
# 1155  https://scistarter.com/project/16909-PlntNet-P...       16909
# 1156  https://scistarter.com/project/16914-Pink-Beds...       16914
# 1158  https://scistarter.com/project/16923-Arcade-Cr...       16923
# 1159  https://scistarter.com/project/16936-Watershed...       16936
# 1160  https://scistarter.com/project/16944-HuMaIN-Hu...       16944
# ...                                                 ...         ...
# 1213     https://scistarter.com/project/17337-cats-cats       17337
# 1214  https://scistarter.com/project/17342-Test-Rio-...       17342
# 1215  https://scistarter.com/project/17343-3D-Printa...       17343
# 1216  https://scistarter.com/project/17350-MO-DIRT-M...       17350
# 1217  https://scistarter.com/project/17351-Project-D...       17351
# 1218  https://scistarter.com/project/17352-Open-Sour...       17352
# 1219  https://scistarter.com/project/17358-Litter-fr...       17358
# 1220  https://scistarter.com/project/17363-Blue-Ridg...       17363
# 1221  https://scistarter.com/project/17375-BeeWise-H...       17375
# 1222  https://scistarter.com/project/17377-Stream-Tr...       17377
# 1223  https://scistarter.com/project/17417-CARIB-Tai...       17417
# 1224  https://scistarter.com/project/17436-MedLit-Bl...       17436
# 1225  https://scistarter.com/project/17441-CosmoQues...       17441
# 1226  https://scistarter.com/project/17443-Satellite...       17443
# 1227  https://scistarter.com/project/17446-Great-Bar...       17446
# 1228  https://scistarter.com/project/17449-Maui-Coas...       17449
# 1229  https://scistarter.com/project/17456-The-River...       17456
# 1230  https://scistarter.com/project/17457-Citizen-S...       17457
# 1231  https://scistarter.com/project/17460-Condor-Wa...       17460
# 1232  https://scistarter.com/project/17461-Petrified...       17461
# 1233  https://scistarter.com/project/17462-Little-Ri...       17462
# 1234  https://scistarter.com/project/17463-Gulf-Isla...       17463
# 1235  https://scistarter.com/project/17468-Power-Sel...       17468
# 1236  https://scistarter.com/project/17472-Aves-da-C...       17472
# 1237  https://scistarter.com/project/17480-Summer-on...       17480
# 1238  https://scistarter.com/project/17481-Chesapeak...       17481
# 1239  https://scistarter.com/project/17491-Ant-Picni...       17491
# 1240  https://scistarter.com/project/17492-Global-Bi...       17492
# 1241  https://scistarter.com/project/17496-Bay-100-B...       17496
# 1350  https://scistarter.com/project/18304-Did-I-see...       18304
#
# [108 rows x 12 columns]

# %%
# Get y_true (the actual projects done by the user) and y_pred (the projects we predicted they would do)
y_true, y_pred = rec.predictions(user_projects, done_projects, top_projects) 

# Evaluate the models precision and recall
precision, recall = evaluate(y_true, y_pred)

# %%
print('--------------------------------')
print('Model Results')
print('Precision: ' + str(precision))
print('Recall: ' + str(recall))
print('--------------------------------')
# Out:
# --------------------------------
# Model Results
# Precision: 0.018518518518518517
# Recall: 0.11764705882352941
# --------------------------------
