# %% [markdown]
# # Unsupervised Clustering of SciStarter Projects

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Load Projects Data

# %%
# Load the projects data from file
projects = pd.read_pickle("../data/raw/project_data")

# %%
# Inspect the projects dataframe
projects.head()
# Out:
#   UN_regions country                                        description error  \
# 0         []          Foldit is a revolutionary new computer game en...   NaN
# 1         []          Firefly Watch combines an annual summer evenin...   NaN
# 2         []          Galaxy Zoo needs your help to classify galaxie...   NaN
# 3         []    None  Pay attention to the plants and animals in you...   NaN
# 4         []          A recent issue of Make magazine (http://makezi...   NaN
#
#                                    guid      origin  \
# 0  5f80760d-8398-5091-b3c6-f34c39216e88  scistarter
# 1  c9664e0c-819a-5a42-b4bb-5f25d83a486d  scistarter
# 2  11f65e99-b463-5e01-ac11-ae59c021dfe7  scistarter
# 3                   wilsoncenter:27-107  scistarter
# 4  ae91e967-6eec-5aef-ab3a-7d86ceff737a  scistarter
#
#                                              regions  \
# 0                                                 []
# 1  [{'geometry': {'type': 'MultiPolygon', 'coordi...
# 2                                                 []
# 3  [{'geometry': {'type': 'MultiPolygon', 'coordi...
# 4                                                 []
#
#                                                 tags  \
# 0                                     [dna, protein]
# 1  [boston, cambridge, fireflies, insects, lightn...
# 2  [astronomy & space, space, space science, zoon...
# 3  [android, animal, animals, app, biology, clima...
# 4                                                 []
#
#                            title  \
# 0                         Foldit
# 1                  Firefly Watch
# 2                     Galaxy Zoo
# 3              Nature's Notebook
# 4  Laser Harp: Build It Yourself
#
#                                               topics  \
# 0       [Computers & Technology, Biology, Chemistry]
# 1  [Nature & Outdoors, Animals, Ecology & Environ...
# 2        [Astronomy & Space, Computers & Technology]
# 3  [Ocean, Water, Marine & Terrestrial, Education...
# 4           [Computers & Technology, Sound, Physics]
#
#                                                  url  project_id
# 0     https://scistarter.com/project/4-Foldit-Foldit           4
# 1  https://scistarter.com/project/5-Firefly-Watch...           5
# 2  https://scistarter.com/project/6-Galaxy-Zoo-Ga...           6
# 3  https://scistarter.com/project/7-Natures-Noteb...           7
# 4  https://scistarter.com/project/8-Laser-Harp-Bu...           8

# %%
# Get the list of unique topics
topics = list(projects['topics'])
flatten = lambda l: [item for sublist in l for item in sublist]
flattened_topics = flatten(topics)
unique_topics = list(set(flattened_topics))

print('There are ' + str(len(unique_topics)) + ' topics')
print(unique_topics)
# Out:
# There are 27 topics
# ['Animals', 'Geography', 'Social Science', 'Health & Medicine', 'Birds', 'Ocean, Water, Marine & Terrestrial', 'Science Policy', 'Climate & Weather', 'Computers & Technology', 'Insects & Pollinators', 'Agriculture', 'Events', 'Awards', 'Psychology', 'Food', 'Nature & Outdoors', 'Ecology & Environment', 'Chemistry', 'Geology & Earth Science', 'Education', 'Archeology & Cultural', 'Transportation', 'Biology', 'Sound', 'Astronomy & Space', 'Physics', 'Crowd Funding']

# %% [markdown]
# Since there are 27 topics, we should first attempt to cluster our projects into 27 clusters

# %%
# Extract the description from the projects
titles = projects['description']

# %% [markdown]
# ### TF-IDF Vectors for Project Titles

# %%
# Create our TF-IDF vectors for the project descriptions vocabulary
vectorizer = TfidfVectorizer(stop_words='english')
X = vectorizer.fit_transform(titles)

# %% [markdown]
# ### Cluster Projects

# %%
# Create 27 clusters based on the project descriptions
true_k = 27
model = KMeans(n_clusters=true_k, init='k-means++', max_iter=100, n_init=1)
model.fit(X)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=100,
#        n_clusters=27, n_init=1, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
# Make predictions for each project in the dataset
predicted = model.predict(X)
projects['predicted_cluster'] = predicted

# %% [markdown]
# ### Examine Clusters

# %%
clusters = projects.groupby('predicted_cluster')['topics'].agg(['size', 'sum']).reset_index()
clusters = clusters.rename(index=str, columns={"sum": "topics"})
clusters['unique_topics'] = clusters['topics'].apply(set)
clusters['topics_count'] =  clusters['unique_topics'].apply(len)
clusters
# Out:
#     predicted_cluster  size  \
# 0                   0   396
# 1                   1    59
# 2                   2   135
# 3                   3    42
# 4                   4    30
# 5                   5    75
# 6                   6    15
# 7                   7    30
# 8                   8    33
# 9                   9    52
# 10                 10    44
# 11                 11    70
# 12                 12    96
# 13                 13    33
# 14                 14    67
# 15                 15    44
# 16                 16    49
# 17                 17    57
# 18                 18    46
# 19                 19    30
# 20                 20    46
# 21                 21    54
# 22                 22    14
# 23                 23    37
# 24                 24    98
# 25                 25    84
# 26                 26    45
#
#                                                topics  \
# 0   [Computers & Technology, Biology, Chemistry, A...
# 1   [Nature & Outdoors, Animals, Ecology & Environ...
# 2   [Computers & Technology, Nature & Outdoors, An...
# 3   [Animals, Health & Medicine, Social Science, G...
# 4   [Nature & Outdoors, Ecology & Environment, Ins...
# 5   [Climate & Weather, Archeology & Cultural, Ani...
# 6   [Biology, Insects & Pollinators, Sound, Comput...
# 7   [Nature & Outdoors, Biology, Geology & Earth S...
# 8   [Computers & Technology, Physics, Biology, Hea...
# 9   [Astronomy & Space, Astronomy & Space, Compute...
# 10  [Nature & Outdoors, Biology, Computers & Techn...
# 11  [Ocean, Water, Marine & Terrestrial, Education...
# 12  [Climate & Weather, Computers & Technology, Na...
# 13  [Computers & Technology, Physics, Nature & Out...
# 14  [Ocean, Water, Marine & Terrestrial, Education...
# 15  [Nature & Outdoors, Animals, Ocean, Water, Mar...
# 16  [Education, Geography, Ecology & Environment, ...
# 17  [Ocean, Water, Marine & Terrestrial, Events, B...
# 18  [Nature & Outdoors, Animals, Insects & Pollina...
# 19  [Nature & Outdoors, Animals, Ocean, Water, Mar...
# 20  [Nature & Outdoors, Animals, Birds, Ecology & ...
# 21  [Nature & Outdoors, Animals, Geology & Earth S...
# 22  [Animals, Birds, Geology & Earth Science, Biol...
# 23  [Biology, Insects & Pollinators, Nature & Outd...
# 24  [Nature & Outdoors, Biology, Chemistry, Ecolog...
# 25  [Nature & Outdoors, Animals, Ecology & Environ...
# 26  [Ecology & Environment, Ocean, Water, Marine &...
#
#                                         unique_topics  topics_count
# 0   {Animals, Geography, Social Science, Health & ...            27
# 1   {Animals, Geography, Social Science, Health & ...            20
# 2   {Animals, Geography, Social Science, Health & ...            27
# 3   {Animals, Geography, Social Science, Health & ...            24
# 4   {Insects & Pollinators, Animals, Computers & T...            12
# 5   {Animals, Social Science, Health & Medicine, B...            24
# 6   {Computers & Technology, Animals, Insects & Po...            10
# 7   {Archeology & Cultural, Computers & Technology...            17
# 8   {Animals, Geography, Social Science, Health & ...            27
# 9   {Animals, Geography, Social Science, Health & ...            23
# 10  {Computers & Technology, Animals, Insects & Po...            16
# 11  {Animals, Geography, Social Science, Health & ...            25
# 12  {Animals, Geography, Social Science, Health & ...            27
# 13  {Animals, Geography, Social Science, Health & ...            21
# 14  {Animals, Geography, Social Science, Health & ...            23
# 15  {Computers & Technology, Animals, Geography, S...            17
# 16  {Archeology & Cultural, Insects & Pollinators,...            18
# 17  {Insects & Pollinators, Animals, Computers & T...            17
# 18  {Animals, Geography, Social Science, Health & ...            27
# 19  {Insects & Pollinators, Animals, Computers & T...            12
# 20  {Insects & Pollinators, Animals, Computers & T...            16
# 21  {Animals, Geography, Social Science, Health & ...            23
# 22  {Geology & Earth Science, Biology, Animals, Bi...             4
# 23  {Insects & Pollinators, Animals, Computers & T...            18
# 24  {Animals, Geography, Social Science, Health & ...            19
# 25  {Animals, Geography, Social Science, Health & ...            25
# 26  {Animals, Geography, Social Science, Health & ...            19

# %%
sns.countplot(x="predicted_cluster", data=projects)

# %% [markdown]
# We can see that aside from Cluster 0, we have a reasonably even spread of projects per cluster. These clusters can then be used as a basic form of recommendation
