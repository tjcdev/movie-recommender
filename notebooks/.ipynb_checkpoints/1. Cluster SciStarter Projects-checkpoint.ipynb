# %% [markdown]
# # Unsupervised Clustering of SciStarter Projects

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Load Projects Data

# %%
# Load the projects data from file
projects = pd.read_pickle("../data/raw/project_data")

# %%
# Inspect the projects dataframe
projects.head()
# Out:
#   UN_regions country                                        description error  \
# 0         []          Foldit is a revolutionary new computer game en...   NaN
# 1         []          Firefly Watch combines an annual summer evenin...   NaN
# 2         []          Galaxy Zoo needs your help to classify galaxie...   NaN
# 3         []    None  Pay attention to the plants and animals in you...   NaN
# 4         []          A recent issue of Make magazine (http://makezi...   NaN
#
#                                    guid      origin  \
# 0  5f80760d-8398-5091-b3c6-f34c39216e88  scistarter
# 1  c9664e0c-819a-5a42-b4bb-5f25d83a486d  scistarter
# 2  11f65e99-b463-5e01-ac11-ae59c021dfe7  scistarter
# 3                   wilsoncenter:27-107  scistarter
# 4  ae91e967-6eec-5aef-ab3a-7d86ceff737a  scistarter
#
#                                              regions  \
# 0                                                 []
# 1  [{'geometry': {'type': 'MultiPolygon', 'coordi...
# 2                                                 []
# 3  [{'geometry': {'type': 'MultiPolygon', 'coordi...
# 4                                                 []
#
#                                                 tags  \
# 0                                     [dna, protein]
# 1  [boston, cambridge, fireflies, insects, lightn...
# 2  [astronomy & space, space, space science, zoon...
# 3  [android, animal, animals, app, biology, clima...
# 4                                                 []
#
#                            title  \
# 0                         Foldit
# 1                  Firefly Watch
# 2                     Galaxy Zoo
# 3              Nature's Notebook
# 4  Laser Harp: Build It Yourself
#
#                                               topics  \
# 0       [Computers & Technology, Biology, Chemistry]
# 1  [Nature & Outdoors, Animals, Ecology & Environ...
# 2        [Astronomy & Space, Computers & Technology]
# 3  [Ocean, Water, Marine & Terrestrial, Education...
# 4           [Computers & Technology, Sound, Physics]
#
#                                                  url  project_id
# 0     https://scistarter.com/project/4-Foldit-Foldit           4
# 1  https://scistarter.com/project/5-Firefly-Watch...           5
# 2  https://scistarter.com/project/6-Galaxy-Zoo-Ga...           6
# 3  https://scistarter.com/project/7-Natures-Noteb...           7
# 4  https://scistarter.com/project/8-Laser-Harp-Bu...           8

# %%
# Get the list of unique topics
topics = list(projects['topics'])
flatten = lambda l: [item for sublist in l for item in sublist]
flattened_topics = flatten(topics)
unique_topics = list(set(flattened_topics))

print('There are ' + str(len(unique_topics)) + ' topics')
print(unique_topics)
# Out:
# There are 27 topics
# ['Ecology & Environment', 'Computers & Technology', 'Animals', 'Insects & Pollinators', 'Astronomy & Space', 'Geography', 'Biology', 'Science Policy', 'Education', 'Psychology', 'Transportation', 'Chemistry', 'Ocean, Water, Marine & Terrestrial', 'Social Science', 'Archeology & Cultural', 'Geology & Earth Science', 'Events', 'Food', 'Sound', 'Nature & Outdoors', 'Physics', 'Climate & Weather', 'Crowd Funding', 'Health & Medicine', 'Birds', 'Agriculture', 'Awards']

# %% [markdown]
# Since there are 27 topics, we should first attempt to cluster our projects into 27 clusters

# %%
# Extract the description from the projects
titles = projects['description']

# %% [markdown]
# ### TF-IDF Vectors for Project Titles

# %%
# Create our TF-IDF vectors for the project descriptions vocabulary
vectorizer = TfidfVectorizer(stop_words='english')
X = vectorizer.fit_transform(titles)

# %% [markdown]
# ### Cluster Projects

# %%
# Create 27 clusters based on the project descriptions
true_k = 27
model = KMeans(n_clusters=true_k, init='k-means++', max_iter=100, n_init=1)
model.fit(X)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=100,
#        n_clusters=27, n_init=1, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
# Make predictions for each project in the dataset
predicted = model.predict(X)
projects['predicted_cluster'] = predicted

# %% [markdown]
# ### Examine Clusters

# %%
clusters = projects.groupby('predicted_cluster')['topics'].agg(['size', 'sum']).reset_index()
clusters = clusters.rename(index=str, columns={"sum": "topics"})
clusters['unique_topics'] = clusters['topics'].apply(set)
clusters['topics_count'] =  clusters['unique_topics'].apply(len)
clusters
# Out:
#     predicted_cluster  size  \
# 0                   0    70
# 1                   1    30
# 2                   2    76
# 3                   3    92
# 4                   4    57
# 5                   5   113
# 6                   6    33
# 7                   7   170
# 8                   8    41
# 9                   9    62
# 10                 10    33
# 11                 11    29
# 12                 12    28
# 13                 13    45
# 14                 14    32
# 15                 15    28
# 16                 16    61
# 17                 17    48
# 18                 18   440
# 19                 19    53
# 20                 20    16
# 21                 21    27
# 22                 22    56
# 23                 23    59
# 24                 24    31
# 25                 25    45
# 26                 26     6
#
#                                                topics  \
# 0   [Nature & Outdoors, Biology, Chemistry, Ecolog...
# 1   [Nature & Outdoors, Geology & Earth Science, A...
# 2   [Ecology & Environment, Ocean, Water, Marine &...
# 3   [Nature & Outdoors, Animals, Ocean, Water, Mar...
# 4   [Events, Ecology & Environment, Birds, Biology...
# 5   [Biology, Computers & Technology, Health & Med...
# 6   [Transportation, Science Policy, Nature & Outd...
# 7   [Nature & Outdoors, Animals, Ecology & Environ...
# 8   [Computers & Technology, Geology & Earth Scien...
# 9   [Climate & Weather, Education, Nature & Outdoo...
# 10  [Nature & Outdoors, Animals, Computers & Techn...
# 11  [Ecology & Environment, Ocean, Water, Marine &...
# 12  [Nature & Outdoors, Ecology & Environment, Oce...
# 13  [Nature & Outdoors, Biology, Birds, Ecology & ...
# 14  [Nature & Outdoors, Ecology & Environment, Ins...
# 15  [Nature & Outdoors, Animals, Ecology & Environ...
# 16  [Ocean, Water, Marine & Terrestrial, Education...
# 17  [Computers & Technology, Physics, Nature & Out...
# 18  [Computers & Technology, Biology, Chemistry, C...
# 19  [Nature & Outdoors, Biology, Ecology & Environ...
# 20  [Ocean, Water, Marine & Terrestrial, Education...
# 21  [Nature & Outdoors, Animals, Birds, Ecology & ...
# 22  [Nature & Outdoors, Biology, Geology & Earth S...
# 23  [Nature & Outdoors, Animals, Ocean, Water, Mar...
# 24  [Computers & Technology, Sound, Physics, Agric...
# 25  [Education, Geography, Ecology & Environment, ...
# 26                                                 []
#
#                                         unique_topics  topics_count
# 0   {Ecology & Environment, Biology, Computers & T...            17
# 1   {Ecology & Environment, Biology, Computers & T...            17
# 2   {Ecology & Environment, Biology, Computers & T...            20
# 3   {Ecology & Environment, Computers & Technology...            27
# 4   {Ecology & Environment, Biology, Computers & T...            18
# 5   {Ecology & Environment, Computers & Technology...            27
# 6   {Ecology & Environment, Biology, Computers & T...            17
# 7   {Ecology & Environment, Computers & Technology...            26
# 8   {Ecology & Environment, Computers & Technology...            25
# 9   {Ecology & Environment, Computers & Technology...            24
# 10  {Ecology & Environment, Biology, Computers & T...            17
# 11  {Ecology & Environment, Biology, Animals, Educ...            17
# 12  {Ecology & Environment, Biology, Computers & T...            17
# 13  {Ecology & Environment, Biology, Computers & T...            13
# 14  {Ecology & Environment, Biology, Computers & T...            12
# 15  {Ecology & Environment, Biology, Computers & T...            11
# 16  {Ecology & Environment, Biology, Computers & T...            19
# 17  {Ecology & Environment, Computers & Technology...            25
# 18  {Ecology & Environment, Computers & Technology...            27
# 19  {Ecology & Environment, Computers & Technology...            27
# 20  {Ecology & Environment, Biology, Computers & T...            12
# 21  {Ecology & Environment, Biology, Computers & T...            16
# 22  {Ecology & Environment, Biology, Computers & T...            19
# 23  {Ecology & Environment, Biology, Computers & T...            19
# 24  {Ecology & Environment, Computers & Technology...            24
# 25  {Ecology & Environment, Biology, Computers & T...            19
# 26                                                 {}             0

# %%
sns.countplot(x="predicted_cluster", data=projects)

# %% [markdown]
# We can see that aside from Cluster 18, we have a reasonably even spread of projects per cluster. These clusters can then be used as a basic form of recommendation.
